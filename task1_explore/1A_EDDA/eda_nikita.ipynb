# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("C:/Users/Nikita/OneDrive/Desktop/Course_Materials/Data Mining Techniques/Assignments/data-mining-techniques/task1_explore/1A_EDDA/teacher_data/ODI-2022.csv", sep=";")
#data.head()
df = data.set_axis(['Time', 'Program', 'ML_course?', 'Info_Retrival_course?', 'Stats_course?', 'Database_course?', 'Gender', 'Chocolate_effect?', 'DateOfBirth', 'Num_neighbours', 'Stand_up?', 'Stress_level', 'Amt_money', 'Rand_num', 'Bedtime', 'Goodday_1?', 'Goodday_2?'], axis=1, inplace=False)
df.head()
# Out:
#                 Time                             Program ML_course?  \
# 0  4-5-2022 12:12:07             artificial intelligence        yes
# 1  4-5-2022 12:12:07                            big data        yes
# 2  4-5-2022 12:12:09              Computational  Science        yes
# 3  4-5-2022 12:12:09  Bioinformatics and Systems Biology        yes
# 4  4-5-2022 12:12:15                                  AI        yes
#
#   Info_Retrival_course? Stats_course? Database_course?  Gender  \
# 0                     0            mu              nee  female
# 1                     0            mu              nee    male
# 2                     1            mu               ja    male
# 3                     0       unknown              nee    male
# 4                     1            mu               ja    male
#
#   Chocolate_effect? DateOfBirth Num_neighbours Stand_up? Stress_level  \
# 0           neither  02.05.1998              0        no            0
# ...

# %%
df.describe()
# Out:
#                      Time Program ML_course? Info_Retrival_course?  \
# count                 304     304        304                   304
# unique                165     123          3                     3
# top     4-5-2022 12:16:06      AI        yes                     0
# freq                    9      39        185                   202
#
#        Stats_course? Database_course? Gender Chocolate_effect? DateOfBirth  \
# count            304              304    304               304         304
# unique             3                3      5                 5         295
# top               mu               ja   male           neither  08-05-1998
# freq             243              158    183               105           3
#
#        Num_neighbours Stand_up? Stress_level Amt_money Rand_num Bedtime  \
# count             304       304          304       303      304     302
# unique             30         3           77       109      142     177
# ...

# %%
# Check for missing values
df.isnull()
# Out:
#       Time  Program  ML_course?  Info_Retrival_course?  Stats_course?  \
# 0    False    False       False                  False          False
# 1    False    False       False                  False          False
# 2    False    False       False                  False          False
# 3    False    False       False                  False          False
# 4    False    False       False                  False          False
# ..     ...      ...         ...                    ...            ...
# 299  False    False       False                  False          False
# 300  False    False       False                  False          False
# 301  False    False       False                  False          False
# 302  False    False       False                  False          False
# 303  False    False       False                  False          False
#
#      Database_course?  Gender  Chocolate_effect?  DateOfBirth  Num_neighbours  \
# ...

# %%
df.notnull()
# Out:
#      Time  Program  ML_course?  Info_Retrival_course?  Stats_course?  \
# 0    True     True        True                   True           True
# 1    True     True        True                   True           True
# 2    True     True        True                   True           True
# 3    True     True        True                   True           True
# 4    True     True        True                   True           True
# ..    ...      ...         ...                    ...            ...
# 299  True     True        True                   True           True
# 300  True     True        True                   True           True
# 301  True     True        True                   True           True
# 302  True     True        True                   True           True
# 303  True     True        True                   True           True
#
#      Database_course?  Gender  Chocolate_effect?  DateOfBirth  Num_neighbours  \
# ...

# %%
df.isna().sum()
# Out:
# Time                     0
# Program                  0
# ML_course?               0
# Info_Retrival_course?    0
# Stats_course?            0
# Database_course?         0
# Gender                   0
# Chocolate_effect?        0
# DateOfBirth              0
# Num_neighbours           0
# Stand_up?                0
# Stress_level             0
# Amt_money                1
# Rand_num                 0
# Bedtime                  2
# Goodday_1?               0
# Goodday_2?               0
# dtype: int64

# %%
df['Program'].unique()
# Out:
# array(['artificial intelligence', 'big data', 'Computational  Science',
#        'Bioinformatics and Systems Biology', 'AI',
#        'Artificial Intelligence', 'Artificial Intelligence ',
#        'M Artificial Intelligence', 'FinTech',
#        'Artificial Intelligence MsC', 'Business analytics', 'ai',
#        'programme?', 'Masters in Artificial Intelligence',
#        'Msc. Information Studies Data Science Track UVA ',
#        'Econometrics and Operational Research', 'Finance and Technology',
#        'Computer science', 'Business Analytics', 'Computational Science',
#        'chrome', 'MSc Mathematics', 'Econometrics', 'AI for health',
#        'Data Mining techniques', 'computer scienece', 'Msc AI @ UvA',
#        'Econometrics & Operations Research',
#        'Master Artificial Intelligence', 'Artificial intelligence ',
#        'Data Science', 'MSc Econometrics & Operations Research',
#        'Computational science', 'MSc AI',
# ...

# %%
df['ML_course?'].unique()
# Out:
# array(['yes', 'no', 'unknown'], dtype=object)

# %%
df['Info_Retrival_course?'].unique()
# Out:
# array(['0', '1', 'unknown'], dtype=object)

# %%
df['Stats_course?'].unique()
# Out:
# array(['mu', 'unknown', 'sigma'], dtype=object)

# %%
df['Database_course?'].unique()
# Out:
# array(['nee', 'ja', 'unknown'], dtype=object)

# %%
df['Gender'].unique()
# Out:
# array(['female', 'male', 'not willing to answer', 'intersex',
#        'gender fluid'], dtype=object)

# %%
df['Chocolate_effect?'].unique()
# Out:
# array(['neither', 'fat', 'I have no idea what you are talking about',
#        'slim', 'unknown'], dtype=object)

# %%
df['Goodday_1?'].unique()
# Out:
# array(['coffee', '7777', '0', 'good food', 'Sunshine', 'This lecture',
#        'sunshine', 'Rainy Day', 'Food', 'sun, friends and wine', 'Coffee',
#        'sun', 'drugs', 'Good sleep', 'Good mental state.', '6', 'food',
#        'Having a fun lecture', 'Flat white', 'Friends', 'Happy',
#        'See you smile', 'Having my favorite meal :)', 'Head',
#        'A good balance between productivity and rest', 'Movies',
#        'Good food', 'Sunnnn', 'alcohol', 'Datamining', 'Weather', 'Sex',
#        '1', 'Working hard', 'Beer', 'good night of sleep', 'Good weather',
#        'Saturday', 'Seeing Friends', 'Satisfaction', '2', 'Chocolate',
#        'Yes', 'Snacks', 'With family and loved ones', 'Sun', 'Cookies',
#        'Biking ', 'waking up early', 'Gym', 'whole lotta bread', '420',
#        'Having a snickers ', 'Free food', 'sleep', 'alive',
#        'No deadlines/exam', 'waking up ', 'Good food and sports',
# ...

# %%
df['Goodday_2?'].unique()
# Out:
# array(['sun', '8964', '0', 'no stress', 'Good Food', 'Sun', 'happiness',
#        'Weekend', 'Relaxation', 'relaxing, watching a show, hockey',
#        'Not coffee', 'holiday', 'beer', 'Good work', 'A challenge.', '9',
#        'sleeping', 'Hanging out with my friends', 'tv series',
#        'good food', 'wind:(', 'Water', 'Faces', 'Monk',
#        'Getting enough sleep', 'Good weather', 'A good night of sleep',
#        'Coffee', 'Croissant', 'relax', 'Datamining2', 'sleep', 'Beer',
#        'Good food', '1', 'Playing volleyball', 'Friends', 'Ajax',
#        'Nice people around', 'Saturday', 'Nice weather', 'Spare time',
#        '4', 'beach', 'Clear skies', 'No', 'gym', 'Good grades',
#        'Being in good health', 'Sleep', 'More beer', "I don't know ",
#        'Food', 'Books', 'finishing things for the day', 'good wave check',
#        'Good coffee', '69', 'Free coffee', 'Chocolate Milk', 'eat',
#        'awake', 'not rain', 'Good sex', 'eating', '10',
# ...

# %%
# Group data in 'Goodday' arrays above in few common groups?
# eg. all sun/weather related answers == 'good weather' 
# eg. all sleep related answers == 'good sleep'
# all food related to answers == 'food'
# ... etc.

# Possible categories: 
# 1. weather/sunny
# 2. food/drinks
# 3. sleep
# 4. friends/family/social interaction
# 5. sports/exercise
# 6. music
# 7. tv
# 8. study/productivity
# 9. other - anything that does that fall in the above category

# %%
df['Stress_level'].value_counts().plot(kind='bar', color="darkgreen")
#df.hist(column='Subject_1');
# Out:
# <AxesSubplot:>

# %%
df['Bedtime'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df['Amt_money'].value_counts().plot(kind='bar', color='orange')
# Out:
# <AxesSubplot:>

# %%
def handle_non_numerical_data(df):
    columns = df.columns.values
    for column in columns:
        text_digit_vals = {}
        def convert_to_int(val):
            return text_digit_vals[val]

        if df[column].dtype != np.int64 and df[column].dtype != np.float64:
            column_contents = df[column].values.tolist()
            unique_elements = set(column_contents)
            x = 0
            for unique in unique_elements:
                if unique not in text_digit_vals:
                    text_digit_vals[unique] = x
                    x+=1

            df[column] = list(map(convert_to_int, df[column]))

    return df

num_df = handle_non_numerical_data(df)
print(num_df.head())
# Out:
#    Time  Program  ML_course?  Info_Retrival_course?  Stats_course?  \
# 0    57       24           0                      2              1
# 1    57       76           0                      2              1
# 2   148       92           0                      0              1
# 3   148       67           0                      2              0
# 4    47        4           0                      0              1
#
#    Database_course?  Gender  Chocolate_effect?  DateOfBirth  Num_neighbours  \
# 0                 1       2                  2          203              23
# 1                 1       1                  3          192              23
# 2                 0       1                  3           29              26
# 3                 1       1                  2          213              23
# 4                 0       1                  3          209              23
#
#    Stand_up?  Stress_level  Amt_money  Rand_num  Bedtime  Goodday_1?  \
# ...

# %%
df.head()
# Out:
#                 Time                             Program ML_course?  \
# 0  4-5-2022 12:12:07             artificial intelligence        yes
# 1  4-5-2022 12:12:07                            big data        yes
# 2  4-5-2022 12:12:09              Computational  Science        yes
# 3  4-5-2022 12:12:09  Bioinformatics and Systems Biology        yes
# 4  4-5-2022 12:12:15                                  AI        yes
#
#   Info_Retrival_course? Stats_course? Database_course?  Gender  \
# 0                     0            mu              nee  female
# 1                     0            mu              nee    male
# 2                     1            mu               ja    male
# 3                     0       unknown              nee    male
# 4                     1            mu               ja    male
#
#   Chocolate_effect? DateOfBirth Num_neighbours Stand_up? Stress_level  \
# 0           neither  02.05.1998              0        no            0
# ...
